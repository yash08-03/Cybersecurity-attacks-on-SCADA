# %%
import pandas as pd 
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/cleaned_ids2018_sampled.csv")

# %%
df=df.reset_index()
df['Label']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 1252841    1
# 1252842    1
# 1252843    1
# 1252844    1
# 1252845    1
# Name: Label, Length: 1252846, dtype: int64

# %%
df1=df.loc[df['Label'] == 1]
df1=df1.head(250000)
df4=df.loc[df['Label'] == 4]
df4=df4.head(250000)
df5=df.loc[df['Label'] == 5]
df5=df5.head(100000)
df2=df.loc[df['Label'] == 2]
df3=df.loc[df['Label'] == 3]
df6=df.loc[df['Label'] == 6]
df7=df.loc[df['Label'] == 7]
df8=df.loc[df['Label'] == 8]
df9=df.loc[df['Label'] == 9]
df10=df.loc[df['Label'] == 10]
df11=df.loc[df['Label'] == 11]

# %%
merge = [
    df1, 
    df2,
    df3,
    df4,
    df5,
    df6, 
    df7
]
df = pd.concat(merge)
del merge
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531329 entries, 0 to 1252199
# Data columns (total 80 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              531329 non-null  int64
#  1   Unnamed: 0         531329 non-null  int64
#  2   Dst Port           531329 non-null  int64
#  3   Protocol           531329 non-null  int64
#  4   Flow Duration      531329 non-null  int64
#  5   Tot Fwd Pkts       531329 non-null  int64
#  6   Tot Bwd Pkts       531329 non-null  int64
#  7   TotLen Fwd Pkts    531329 non-null  int64
#  8   TotLen Bwd Pkts    531329 non-null  int64
#  9   Fwd Pkt Len Max    531329 non-null  int64
#  10  Fwd Pkt Len Min    531329 non-null  int64
#  11  Fwd Pkt Len Mean   531329 non-null  float64
#  12  Fwd Pkt Len Std    531329 non-null  float64
#  13  Bwd Pkt Len Max    531329 non-null  int64
#  14  Bwd Pkt Len Min    531329 non-null  int64
#  15  Bwd Pkt Len Mean   531329 non-null  float64
#  16  Bwd Pkt Len Std    531329 non-null  float64
#  17  Flow Byts/s        531329 non-null  float64
#  18  Flow Pkts/s        531329 non-null  float64
#  19  Flow IAT Mean      531329 non-null  float64
#  20  Flow IAT Std       531329 non-null  float64
#  21  Flow IAT Max       531329 non-null  int64
#  22  Flow IAT Min       531329 non-null  int64
#  23  Fwd IAT Tot        531329 non-null  int64
#  24  Fwd IAT Mean       531329 non-null  float64
#  25  Fwd IAT Std        531329 non-null  float64
#  26  Fwd IAT Max        531329 non-null  int64
#  27  Fwd IAT Min        531329 non-null  int64
#  28  Bwd IAT Tot        531329 non-null  int64
#  29  Bwd IAT Mean       531329 non-null  float64
#  30  Bwd IAT Std        531329 non-null  float64
#  31  Bwd IAT Max        531329 non-null  int64
#  32  Bwd IAT Min        531329 non-null  int64
#  33  Fwd PSH Flags      531329 non-null  int64
#  34  Bwd PSH Flags      531329 non-null  int64
#  35  Fwd URG Flags      531329 non-null  int64
#  36  Bwd URG Flags      531329 non-null  int64
#  37  Fwd Header Len     531329 non-null  int64
#  38  Bwd Header Len     531329 non-null  int64
#  39  Fwd Pkts/s         531329 non-null  float64
#  40  Bwd Pkts/s         531329 non-null  float64
#  41  Pkt Len Min        531329 non-null  int64
#  42  Pkt Len Max        531329 non-null  int64
#  43  Pkt Len Mean       531329 non-null  float64
#  44  Pkt Len Std        531329 non-null  float64
#  45  Pkt Len Var        531329 non-null  float64
#  46  FIN Flag Cnt       531329 non-null  int64
#  47  SYN Flag Cnt       531329 non-null  int64
#  48  RST Flag Cnt       531329 non-null  int64
#  49  PSH Flag Cnt       531329 non-null  int64
#  50  ACK Flag Cnt       531329 non-null  int64
#  51  URG Flag Cnt       531329 non-null  int64
#  52  CWE Flag Count     531329 non-null  int64
#  53  ECE Flag Cnt       531329 non-null  int64
#  54  Pkt Size Avg       531329 non-null  float64
#  55  Fwd Seg Size Avg   531329 non-null  float64
#  56  Bwd Seg Size Avg   531329 non-null  float64
#  57  Fwd Byts/b Avg     531329 non-null  int64
#  58  Fwd Pkts/b Avg     531329 non-null  int64
#  59  Fwd Blk Rate Avg   531329 non-null  int64
#  60  Bwd Byts/b Avg     531329 non-null  int64
#  61  Bwd Pkts/b Avg     531329 non-null  int64
#  62  Bwd Blk Rate Avg   531329 non-null  int64
#  63  Subflow Fwd Pkts   531329 non-null  int64
#  64  Subflow Fwd Byts   531329 non-null  int64
#  65  Subflow Bwd Pkts   531329 non-null  int64
#  66  Subflow Bwd Byts   531329 non-null  int64
#  67  Init Fwd Win Byts  531329 non-null  int64
#  68  Init Bwd Win Byts  531329 non-null  int64
#  69  Fwd Act Data Pkts  531329 non-null  int64
#  70  Fwd Seg Size Min   531329 non-null  int64
#  71  Active Mean        531329 non-null  float64
#  72  Active Std         531329 non-null  float64
#  73  Active Max         531329 non-null  int64
#  74  Active Min         531329 non-null  int64
#  75  Idle Mean          531329 non-null  float64
#  76  Idle Std           531329 non-null  float64
#  77  Idle Max           531329 non-null  int64
#  78  Idle Min           531329 non-null  int64
#  79  Label              531329 non-null  int64
# dtypes: float64(24), int64(56)
# memory usage: 328.4 MB

# %%
df=df.reset_index()

# %%
import numpy as np
dfnew=df
# dfnew['Label'] = np.where(dfnew['Label'] > 1, 0, dfnew['Label'])
dfnew['Label'].nunique()
# Out:
# 7

# %%
dfnew['Label']=(dfnew['Label']+1)%2
data = dfnew.drop(['index','Unnamed: 0'], axis=1)
data['Label']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 531324    0
# 531325    0
# 531326    0
# 531327    0
# 531328    0
# Name: Label, Length: 531329, dtype: int64

# %% [markdown]
# #KNN

# %%
data = dfnew.drop(['index','Unnamed: 0','level_0'], axis=1)

# %%
data
# Out:
#         Dst Port  Protocol  Flow Duration  ...  Idle Max  Idle Min  Label
# 0           3389         6        5206015  ...         0         0      1
# 1            443         6       60991608  ...  10009249   9968397      1
# 2             53        17          27292  ...         0         0      1
# 3            443         6       70343424  ...  58654921  10485549      1
# 4             53        17         137267  ...         0         0      1
# ...          ...       ...            ...  ...       ...       ...    ...
# 531324        80         6       99999918  ...  99999902  99999902      7
# 531325        80         6      107187709  ...  53236643   6649249      7
# 531326        80         6      107646209  ...  53247494   6656083      7
# 531327        80         6      107133998  ...  53247454   6655803      7
# 531328        80         6      107837624  ...  53247403   6655939      7
#
# [531329 rows x 78 columns]

# %%
X=data.drop(['Label'], axis=1)
y=data['Label']

# %%
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)
 
# training a KNN classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train)
 
# accuracy on X_test
accuracy = knn.score(X_test, y_test)
print(accuracy)
# Out:
# 0.997749053322593

# %%
# creating a confusion matrix
knn_predictions = knn.predict(X_test)
cm = confusion_matrix(y_test, knn_predictions)

# %%
import seaborn as sns
sns.heatmap(cm, annot=True)

# %%
X=data[['Init Fwd Win Byts','Dst Port','Fwd Seg Size Min','ACK Flag Cnt','Flow Pkts/s','Bwd Pkts/s','Init Bwd Win Byts','Fwd Pkts/s','RST Flag Cnt','PSH Flag Cnt','ECE Flag Cnt','URG Flag Cnt','Bwd Seg Size Avg','Bwd Pkt Len Max','Bwd Pkt Len Std','Fwd IAT Min','Protocol','Pkt Len Max','Fwd Pkt Len Max','Flow Duration','Label']]

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(X, hue="Label", height=3);
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue='la', size=5) \
.map(plt.scatter, “sepal_length”, “sepal_width”) \
.add_legend();
plt.show()
